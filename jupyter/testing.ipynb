# %%
print("hello world!")
# Out:
# hello world!

# %%
import requests

r = requests.get('https://cdn.jsdelivr.net/gh/fawazahmed0/currency-api@1/latest/currencies/eur.json')
print(r.status_code)
print(r.text)
# Out:
# 200
# {
#     "date": "2023-05-29",
#     "eur": {
#         "1inch": 2.643602,
#         "aave": 0.015518,
#         "ada": 2.780163,
#         "aed": 3.938985,
#         "afn": 94.167518,
#         "algo": 6.975512,
#         "all": 110.717627,
#         "amd": 414.356953,
#         "amp": 403.579562,
#         "ang": 1.937665,
#         "aoa": 592.642755,
#         "ar": 0.1528,
#         "ars": 253.296507,
#         "atom": 0.098022,
#         "aud": 1.639875,
#         "avax": 0.071869,
#         "awg": 1.933452,
#         "axs": 0.14947,
#         "azn": 1.824767,
#         "bake": 6.98168,
#         "bam": 1.957014,
#         "bat": 4.757188,
#         "bbd": 2.170826,
#         "bch": 0.009224,
#         "bdt": 115.271483,
#         "bgn": 1.955114,
#         "bhd": 0.405248,
#         "bif": 3033.052597,
#         "bmd": 1.07265,
#         "bnb": 0.003401,
#         "bnd": 1.452787,
#         "bob": 7.429607,
#         "brl": 5.358156,
#         "bsd": 1.075147,
# ...
